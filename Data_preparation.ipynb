# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
columns_corn = [ 'Date',
            'Corn Price',
            'CPI',
           	'GPR	Country',
            'GPR',
           	'US Wheat Futures',
           	'Brent Oil Futures',
           	'London Wheat Futures',
           	'Exch Rate',
             'T',
             'TM',
             'Tm',
             'H',
             'PP',
           	 'VV',
             'V',
             'VM',
             'RA',
           	 'SN',
             'TS',
             'FG'  ]

columns_barley = [ 'Date',
            'Barley Price',
            'CPI',
           	'GPR	Country',
            'GPR',
           	'US Wheat Futures',
           	'Brent Oil Futures',
           	'London Wheat Futures',
           	'Exch Rate',
             'T',
             'TM',
             'Tm',
             'H',
             'PP',
           	 'VV',
             'V',
             'VM',
             'RA',
           	 'SN',
             'TS',
             'FG'  ]

df_corn = pd.read_excel('Corn Data.xlsx', header = None, skiprows = 1, names = columns_corn)
df_barley = pd.read_excel('Barley Data.xlsx', header = None, skiprows = 1, names = columns_barley)

# %%
df_corn.head()
# Out:
#         Date  Corn Price    CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 0 2022-02-25        7900  141.7        178.90  322            843.00
# 1 2022-02-18        7750  141.7        178.90  322            797.00
# 2 2022-02-11        7650  141.7        178.90  322            797.75
# 3 2022-02-04        7700  141.7        178.90  322            763.25
# 4 2022-01-28        7750  137.6        140.83  177            786.25
#
#    Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...   Tm  \
# 0              97.93                231.00    30.0500  1.100  ... -2.5
# 1              93.54                222.50    28.4014  1.100  ... -2.5
# 2              94.44                221.05    28.0414  1.100  ... -2.5
# 3              93.27                217.55    28.1140  1.100  ... -2.5
# 4              90.03                221.00    28.6918 -1.925  ... -5.1
#
#         H       PP      VV       V    VM    RA    SN   TS   FG
# 0  78.775  19.1775  10.100  12.775  23.4   9.5   6.0  0.0  1.0
# 1  78.775  19.1775  10.100  12.775  23.4   9.5   6.0  0.0  1.0
# 2  78.775  19.1775  10.100  12.775  23.4   9.5   6.0  0.0  1.0
# 3  78.775  19.1775  10.100  12.775  23.4   9.5   6.0  0.0  1.0
# 4  82.325  51.3725   9.225  16.625  30.3  10.5  20.5  0.0  1.5
#
# [5 rows x 21 columns]

# %%
df_corn.tail()
# Out:
#           Date  Corn Price   CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 629 2010-01-29        1230  98.4         91.58    1            473.13
# 630 2010-01-22        1240  98.4         91.58    1            498.13
# 631 2010-01-15        1250  98.4         91.58    1            509.88
# 632 2010-01-08        1240  98.4         91.58    1            568.13
# 633 2010-01-01        1240  98.4         91.58    1            540.75
#
#      Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...    Tm  \
# 629              71.46                 99.85      8.050 -9.375  ... -14.2
# 630              72.83                100.85      8.110 -9.375  ... -14.2
# 631              77.11                104.00      8.125 -9.375  ... -14.2
# 632              81.37                109.25      8.075 -9.375  ... -14.2
# 633              80.12                110.45      8.050 -9.375  ... -14.2
#
#          H     PP    VV       V    VM    RA     SN   TS    FG
# 629  84.65  47.18  6.95  13.825  21.4  5.25  16.75  0.0  4.75
# 630  84.65  47.18  6.95  13.825  21.4  5.25  16.75  0.0  4.75
# 631  84.65  47.18  6.95  13.825  21.4  5.25  16.75  0.0  4.75
# 632  84.65  47.18  6.95  13.825  21.4  5.25  16.75  0.0  4.75
# 633  84.65  47.18  6.95  13.825  21.4  5.25  16.75  0.0  4.75
#
# [5 rows x 21 columns]

# %%
df_barley.head()
# Out:
#         Date  Barley Price    CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 0 2022-02-25          7650  141.7        178.90  322            843.00
# 1 2022-02-18          7650  141.7        178.90  322            797.00
# 2 2022-02-11          7600  141.7        178.90  322            797.75
# 3 2022-02-04          7700  141.7        178.90  322            763.25
# 4 2022-01-28          7600  137.6        140.83  177            786.25
#
#    Brent Oil Futures  London Wheat Futures  Exch Rate     T  ...   Tm       H  \
# 0              97.93                231.00    30.0500  2.65  ... -1.9  79.350
# 1              93.54                222.50    28.4014  2.65  ... -1.9  79.350
# 2              94.44                221.05    28.0414  2.65  ... -1.9  79.350
# 3              93.27                217.55    28.1140  2.65  ... -1.9  79.350
# 4              90.03                221.00    28.6918  0.15  ... -5.9  83.425
#
#         PP     VV      V    VM     RA     SN   TS    FG
# 0   6.0325  8.725  12.95  25.9   9.50   4.75  0.0  7.25
# 1   6.0325  8.725  12.95  25.9   9.50   4.75  0.0  7.25
# 2   6.0325  8.725  12.95  25.9   9.50   4.75  0.0  7.25
# 3   6.0325  8.725  12.95  25.9   9.50   4.75  0.0  7.25
# 4  12.3825  8.100  16.75  31.0  11.25  16.75  0.0  6.00
#
# [5 rows x 21 columns]

# %%
df_barley.tail()
# Out:
#           Date  Barley Price   CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 629 2010-01-29           850  98.4         91.58    1            473.13
# 630 2010-01-22           860  98.4         91.58    1            498.13
# 631 2010-01-15           880  98.4         91.58    1            509.88
# 632 2010-01-08           880  98.4         91.58    1            568.13
# 633 2010-01-01           880  98.4         91.58    1            540.75
#
#      Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...   Tm  \
# 629              71.46                 99.85      8.050 -5.125  ... -9.6
# 630              72.83                100.85      8.110 -5.125  ... -9.6
# 631              77.11                104.00      8.125 -5.125  ... -9.6
# 632              81.37                109.25      8.075 -5.125  ... -9.6
# 633              80.12                110.45      8.050 -5.125  ... -9.6
#
#           H     PP     VV     V    VM    RA    SN    TS    FG
# 629  88.925  52.84  6.375  17.1  30.2  9.25  14.5  0.25  11.0
# 630  88.925  52.84  6.375  17.1  30.2  9.25  14.5  0.25  11.0
# 631  88.925  52.84  6.375  17.1  30.2  9.25  14.5  0.25  11.0
# 632  88.925  52.84  6.375  17.1  30.2  9.25  14.5  0.25  11.0
# 633  88.925  52.84  6.375  17.1  30.2  9.25  14.5  0.25  11.0
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=df_corn.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=df_barley.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_corn["Exchange Rate Change 1"] = df_corn["Exch Rate"].pct_change(periods=1)*100
df_corn["Exchange Rate Change 4"] = df_corn["Exch Rate"].pct_change(periods=4)*100
df_corn["Price Change 1"] = df_corn["Corn Price"].pct_change(periods=1)*100
df_corn["Price Change 4"] = df_corn["Corn Price"].pct_change(periods=4)*100

# %%
df_corn.head()
# Out:
#         Date  Corn Price    CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 0 2022-02-25        7900  141.7        178.90  322            843.00
# 1 2022-02-18        7750  141.7        178.90  322            797.00
# 2 2022-02-11        7650  141.7        178.90  322            797.75
# 3 2022-02-04        7700  141.7        178.90  322            763.25
# 4 2022-01-28        7750  137.6        140.83  177            786.25
#
#    Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...       V  \
# 0              97.93                231.00    30.0500  1.100  ...  12.775
# 1              93.54                222.50    28.4014  1.100  ...  12.775
# 2              94.44                221.05    28.0414  1.100  ...  12.775
# 3              93.27                217.55    28.1140  1.100  ...  12.775
# 4              90.03                221.00    28.6918 -1.925  ...  16.625
#
#      VM    RA    SN   TS   FG  Exchange Rate Change 1  Exchange Rate Change 4  \
# 0  23.4   9.5   6.0  0.0  1.0                     NaN                     NaN
# 1  23.4   9.5   6.0  0.0  1.0               -5.486190                     NaN
# 2  23.4   9.5   6.0  0.0  1.0               -1.267543                     NaN
# 3  23.4   9.5   6.0  0.0  1.0                0.258903                     NaN
# 4  30.3  10.5  20.5  0.0  1.5                2.055204                 -4.5198
#
#    Price Change 1  Price Change 4
# 0             NaN             NaN
# 1       -1.898734             NaN
# 2       -1.290323             NaN
# 3        0.653595             NaN
# 4        0.649351       -1.898734
#
# [5 rows x 25 columns]

# %%
df_corn.tail()
# Out:
#           Date  Corn Price   CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 629 2010-01-29        1230  98.4         91.58    1            473.13
# 630 2010-01-22        1240  98.4         91.58    1            498.13
# 631 2010-01-15        1250  98.4         91.58    1            509.88
# 632 2010-01-08        1240  98.4         91.58    1            568.13
# 633 2010-01-01        1240  98.4         91.58    1            540.75
#
#      Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...       V  \
# 629              71.46                 99.85      8.050 -9.375  ...  13.825
# 630              72.83                100.85      8.110 -9.375  ...  13.825
# 631              77.11                104.00      8.125 -9.375  ...  13.825
# 632              81.37                109.25      8.075 -9.375  ...  13.825
# 633              80.12                110.45      8.050 -9.375  ...  13.825
#
#        VM    RA     SN   TS    FG  Exchange Rate Change 1  \
# 629  21.4  5.25  16.75  0.0  4.75               -0.247831
# 630  21.4  5.25  16.75  0.0  4.75                0.745342
# 631  21.4  5.25  16.75  0.0  4.75                0.184957
# 632  21.4  5.25  16.75  0.0  4.75               -0.615385
# 633  21.4  5.25  16.75  0.0  4.75               -0.309598
#
#      Exchange Rate Change 4  Price Change 1  Price Change 4
# 629                0.349040        1.652893       -0.806452
# 630                0.833023        0.813008        0.000000
# 631                0.806452        0.806452        2.459016
# 632                0.061958       -0.800000        2.479339
# 633                0.000000        0.000000        0.813008
#
# [5 rows x 25 columns]

# %%
df_barley["Exchange Rate Change 1"] = df_barley["Exch Rate"].pct_change(periods=1)*100
df_barley["Exchange Rate Change 4"] = df_barley["Exch Rate"].pct_change(periods=4)*100
df_barley["Price Change 1"] = df_barley["Barley Price"].pct_change(periods=1)*100
df_barley["Price Change 4"] = df_barley["Barley Price"].pct_change(periods=4)*100

# %%
df_barley.head()
# Out:
#         Date  Barley Price    CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 0 2022-02-25          7650  141.7        178.90  322            843.00
# 1 2022-02-18          7650  141.7        178.90  322            797.00
# 2 2022-02-11          7600  141.7        178.90  322            797.75
# 3 2022-02-04          7700  141.7        178.90  322            763.25
# 4 2022-01-28          7600  137.6        140.83  177            786.25
#
#    Brent Oil Futures  London Wheat Futures  Exch Rate     T  ...      V    VM  \
# 0              97.93                231.00    30.0500  2.65  ...  12.95  25.9
# 1              93.54                222.50    28.4014  2.65  ...  12.95  25.9
# 2              94.44                221.05    28.0414  2.65  ...  12.95  25.9
# 3              93.27                217.55    28.1140  2.65  ...  12.95  25.9
# 4              90.03                221.00    28.6918  0.15  ...  16.75  31.0
#
#       RA     SN   TS    FG  Exchange Rate Change 1  Exchange Rate Change 4  \
# 0   9.50   4.75  0.0  7.25                     NaN                     NaN
# 1   9.50   4.75  0.0  7.25               -5.486190                     NaN
# 2   9.50   4.75  0.0  7.25               -1.267543                     NaN
# 3   9.50   4.75  0.0  7.25                0.258903                     NaN
# 4  11.25  16.75  0.0  6.00                2.055204                 -4.5198
#
#    Price Change 1  Price Change 4
# 0             NaN             NaN
# 1        0.000000             NaN
# 2       -0.653595             NaN
# 3        1.315789             NaN
# 4       -1.298701       -0.653595
#
# [5 rows x 25 columns]

# %%
df_barley.tail()
# Out:
#           Date  Barley Price   CPI  GPR\tCountry  GPR  US Wheat Futures  \
# 629 2010-01-29           850  98.4         91.58    1            473.13
# 630 2010-01-22           860  98.4         91.58    1            498.13
# 631 2010-01-15           880  98.4         91.58    1            509.88
# 632 2010-01-08           880  98.4         91.58    1            568.13
# 633 2010-01-01           880  98.4         91.58    1            540.75
#
#      Brent Oil Futures  London Wheat Futures  Exch Rate      T  ...     V  \
# 629              71.46                 99.85      8.050 -5.125  ...  17.1
# 630              72.83                100.85      8.110 -5.125  ...  17.1
# 631              77.11                104.00      8.125 -5.125  ...  17.1
# 632              81.37                109.25      8.075 -5.125  ...  17.1
# 633              80.12                110.45      8.050 -5.125  ...  17.1
#
#        VM    RA    SN    TS    FG  Exchange Rate Change 1  \
# 629  30.2  9.25  14.5  0.25  11.0               -0.247831
# 630  30.2  9.25  14.5  0.25  11.0                0.745342
# 631  30.2  9.25  14.5  0.25  11.0                0.184957
# 632  30.2  9.25  14.5  0.25  11.0               -0.615385
# 633  30.2  9.25  14.5  0.25  11.0               -0.309598
#
#      Exchange Rate Change 4  Price Change 1  Price Change 4
# 629                0.349040        0.591716       -1.162791
# 630                0.833023        1.176471       -1.149425
# 631                0.806452        2.325581        3.529412
# 632                0.061958        0.000000        4.142012
# 633                0.000000        0.000000        3.529412
#
# [5 rows x 25 columns]
